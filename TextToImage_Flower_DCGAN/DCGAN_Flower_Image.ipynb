# %% [markdown]
# **Mounting The Drive To Load Data And Store Models**

# %%
# !pip install torchvision
# !pip install tqdm
# !pip install h5py
# Out:
# Requirement already satisfied: torchvision in /Users/samar/miniforge3/envs/env_tf/lib/python3.9/site-packages (0.12.0)
# Requirement already satisfied: requests in /Users/samar/miniforge3/envs/env_tf/lib/python3.9/site-packages (from torchvision) (2.27.1)
# Requirement already satisfied: torch in /Users/samar/miniforge3/envs/env_tf/lib/python3.9/site-packages (from torchvision) (1.11.0)
# Requirement already satisfied: numpy in /Users/samar/miniforge3/envs/env_tf/lib/python3.9/site-packages (from torchvision) (1.21.5)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /Users/samar/miniforge3/envs/env_tf/lib/python3.9/site-packages (from torchvision) (9.0.1)
# Requirement already satisfied: typing-extensions in /Users/samar/miniforge3/envs/env_tf/lib/python3.9/site-packages (from torchvision) (4.0.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/samar/miniforge3/envs/env_tf/lib/python3.9/site-packages (from requests->torchvision) (1.26.8)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/samar/miniforge3/envs/env_tf/lib/python3.9/site-packages (from requests->torchvision) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in /Users/samar/miniforge3/envs/env_tf/lib/python3.9/site-packages (from requests->torchvision) (3.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Users/samar/miniforge3/envs/env_tf/lib/python3.9/site-packages (from requests->torchvision) (2.0.11)
# Requirement already satisfied: tqdm in /Users/samar/miniforge3/envs/env_tf/lib/python3.9/site-packages (4.64.0)
# Requirement already satisfied: h5py in /Users/samar/miniforge3/envs/env_tf/lib/python3.9/site-packages (3.6.0)
# Requirement already satisfied: numpy>=1.14.5 in /Users/samar/miniforge3/envs/env_tf/lib/python3.9/site-packages (from h5py) (1.21.5)

# %% [markdown]
# **Importing All The Necessary Libraries**

# %%
import torch
import torchvision
import numpy as np
from torch import nn
from tqdm.auto import tqdm
from torchvision import transforms
from torchvision.utils import make_grid
import matplotlib.pyplot as plt
import torch.nn.functional as F
from torchvision.datasets import ImageFolder
from __future__ import print_function
import argparse
import os
import random
import torch.nn as nn
import torch.nn.parallel
import torch.backends.cudnn as cudnn
import torch.optim as optim
import torch.utils.data
import torchvision.datasets as dset
import torchvision.transforms as transforms
import torchvision.utils as vutils
import matplotlib.animation as animation
from IPython.display import HTML
from torch.autograd import Variable
import pdb
import io
from torch.utils.data import Dataset, DataLoader
import h5py
from PIL import Image
ngpu = 4
device = torch.device("cuda:0" if (torch.cuda.is_available() and ngpu > 0) else "cpu")
# %matplotlib inline

# %% [markdown]
# **Generator Model Class**

# %%
def make_gen_block(input_channels, output_channels, kernel_size=2, stride=1, pad = 0, final_layer=False):
    if not final_layer:
        return nn.Sequential(
            nn.ConvTranspose2d(input_channels, output_channels, kernel_size, stride, pad, bias = False),
            nn.BatchNorm2d(output_channels),
            nn.ReLU(inplace=True)
        )
    else: # Final Layer
        return nn.Sequential(
            nn.ConvTranspose2d(input_channels, output_channels, kernel_size, stride, pad, bias = False),
            nn.Tanh()
        )
class Generator(nn.Module):
    def __init__(self):
      super(Generator, self).__init__()
      self.img_size = 64   # Image Size
      self.nc = 3          # Number of Channels
      self.noise_dim = 100 # Z
      self.ngf = 64        # Number of Filters
      self.embed_dim = 1024 # Input Embedding of text
      self.projected_embed_dim = 128 # Projected Embedding of Text Size
      self.latent_dim = self.noise_dim + self.projected_embed_dim # New Z Dimension, adding embedding also
      
      self.generator = nn.Sequential(
          
        make_gen_block(self.latent_dim, self.ngf*8, 4, 1, 0), 
        make_gen_block(self.ngf*8, self.ngf*4, 4, 2, 1),
        make_gen_block(self.ngf*4, self.ngf*2, 4, 2, 1),
        make_gen_block(self.ngf*2, self.ngf, 4, 2, 1),
        make_gen_block(self.ngf, self.nc, 4, 2, 1, True),
        )
      
      self.projection = nn.Sequential(
			  nn.Linear(in_features=self.embed_dim, out_features=self.projected_embed_dim),
			  nn.BatchNorm1d(num_features=self.projected_embed_dim),
			  nn.LeakyReLU(negative_slope=0.2, inplace=True)
			  )
      
    def forward(self, embed_vector, z):
      projected_embed = self.projection(embed_vector).unsqueeze(2).unsqueeze(3) # Converting 1028 to 128 input embedding
      latent_vector = torch.cat([projected_embed, z], 1) # Final Z Vector after concatenation text embedding with noise
      output = self.generator(latent_vector) # Run Generator
      return output

# %% [markdown]
# **Testing And Printing Generator Model**

# %%
def build_gm():
  gmodel = Generator()
  print(gmodel)
  return gmodel
build_gm();   # Making Final Image of 64x64x3
# Out:
# Generator(
#   (generator): Sequential(
#     (0): Sequential(
#       (0): ConvTranspose2d(228, 512, kernel_size=(4, 4), stride=(1, 1), bias=False)
#       (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU(inplace=True)
#     )
#     (1): Sequential(
#       (0): ConvTranspose2d(512, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU(inplace=True)
#     )
#     (2): Sequential(
#       (0): ConvTranspose2d(256, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU(inplace=True)
#     )
#     (3): Sequential(
#       (0): ConvTranspose2d(128, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU(inplace=True)
#     )
#     (4): Sequential(
#       (0): ConvTranspose2d(64, 3, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#       (1): Tanh()
#     )
#   )
#   (projection): Sequential(
#     (0): Linear(in_features=1024, out_features=128, bias=True)
#     (1): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): LeakyReLU(negative_slope=0.2, inplace=True)
#   )
# )

# %% [markdown]
# **Discriminator Model Class**

# %%
class Concat_embed(nn.Module):

    def __init__(self, embed_dim, projected_embed_dim):
        super(Concat_embed, self).__init__()
        self.projection = nn.Sequential(
            nn.Linear(in_features=embed_dim, out_features=projected_embed_dim),
            nn.BatchNorm1d(num_features=projected_embed_dim),
            nn.LeakyReLU(negative_slope=0.2, inplace=True)
            )

    def forward(self, inp, embed):
        projected_embed = self.projection(embed)
        replicated_embed = projected_embed.repeat(4, 4, 1, 1).permute(2,  3, 0, 1)
        hidden_concat = torch.cat([inp, replicated_embed], 1)
        return hidden_concat

def make_disc_block(input_channels, output_channels, kernel_size=4, stride=2, pad = 1, first_layer=False):
        if not first_layer:
            return nn.Sequential(
                nn.Conv2d(input_channels, output_channels, kernel_size, stride, pad), # Normal Conv 2d 
                nn.BatchNorm2d(output_channels),
                nn.LeakyReLU(0.2, inplace=True)
            )
        else:
            return nn.Sequential(
                nn.Conv2d(input_channels, output_channels, kernel_size, stride, pad),
                nn.LeakyReLU(0.2, inplace=True)
            )

class Discriminator(nn.Module):
  def __init__(self):
    super(Discriminator, self).__init__()
    self.img_size = 64
    self.nc = 3
    self.noise_dim = 100
    self.ndf = 64
    self.embed_dim = 1024
    self.projected_embed_dim = 128
    

    self.discriminator1 = nn.Sequential(                    # Convolution layers of Discriminator
        make_disc_block(self.nc, self.ndf, 4, 2, 1, True),  #Decreasing Image size and increasing channels
        make_disc_block(self.ndf, self.ndf*2, 4, 2, 1),
        make_disc_block(self.ndf*2, self.ndf*4, 4, 2, 1),
        make_disc_block(self.ndf*4, self.ndf*8, 4, 2, 1),
        )
    self.projector = Concat_embed(self.embed_dim, self.projected_embed_dim)
    self.discriminator2 = nn.Sequential(
        nn.Conv2d(self.ndf*8 + self.projected_embed_dim, 1, 4, 1, 0, bias = False), # Classifying as True and false
        nn.Sigmoid()
    )

  def forward(self, input, embed):
    x_1 = self.discriminator1(input)     # Generator Input sent to Discriminator
    x = self.projector(x_1, embed)
    output = self.discriminator2(x)      # Getting True/False from Discriminator
    return output.view(-1, 1).squeeze(1), x_1

# %% [markdown]
# **Testing And Printing Discriminator Model**

# %%
def build_dm():
  dmodel = Discriminator()
  print(dmodel)
  return dmodel
build_dm();
# Out:
# Discriminator(
#   (discriminator1): Sequential(
#     (0): Sequential(
#       (0): Conv2d(3, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#       (1): LeakyReLU(negative_slope=0.2, inplace=True)
#     )
#     (1): Sequential(
#       (0): Conv2d(64, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#       (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): LeakyReLU(negative_slope=0.2, inplace=True)
#     )
#     (2): Sequential(
#       (0): Conv2d(128, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#       (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): LeakyReLU(negative_slope=0.2, inplace=True)
#     )
#     (3): Sequential(
#       (0): Conv2d(256, 512, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#       (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): LeakyReLU(negative_slope=0.2, inplace=True)
#     )
#   )
#   (projector): Concat_embed(
#     (projection): Sequential(
#       (0): Linear(in_features=1024, out_features=128, bias=True)
#       (1): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): LeakyReLU(negative_slope=0.2, inplace=True)
#     )
#   )
#   (discriminator2): Sequential(
#     (0): Conv2d(640, 1, kernel_size=(4, 4), stride=(1, 1), bias=False)
#     (1): Sigmoid()
#   )
# )

# %% [markdown]
# **Helper Class to Handle and Transform Input Data**

# %%
class Text2ImageDataset(Dataset):  # Using the hd5 file to get input text embeddings

    def __init__(self, datasetFile, transform=None, split=0):
        self.datasetFile = datasetFile
        self.transform = transform
        self.dataset = None
        self.dataset_keys = None
        self.split = 'train' if split == 0 else 'valid' if split == 1 else 'test'
        self.h5py2int = lambda x: int(np.array(x))

    def __len__(self):
        f = h5py.File(self.datasetFile, 'r')
        self.dataset_keys = [str(k) for k in f[self.split].keys()]
        length = len(f[self.split])
        f.close()

        return length

    def __getitem__(self, idx):    # Opening the dictinary, doing train_test split! 
        if self.dataset is None:
            self.dataset = h5py.File(self.datasetFile, mode='r')
            self.dataset_keys = [str(k) for k in self.dataset[self.split].keys()]

        example_name = self.dataset_keys[idx]
        example = self.dataset[self.split][example_name]

        right_image = bytes(np.array(example['img']))   # Getting images
        right_embed = np.array(example['embeddings'], dtype=float) # Gettinvg Text Embeddings
        wrong_image = bytes(np.array(self.find_wrong_image(example['class']))) # Getting Classes
        inter_embed = np.array(self.find_inter_embed())

        right_image = Image.open(io.BytesIO(right_image)).resize((64, 64))
        wrong_image = Image.open(io.BytesIO(wrong_image)).resize((64, 64))

        right_image = self.validate_image(right_image)
        wrong_image = self.validate_image(wrong_image)

        txt = np.array(example['txt']).astype(str)

        sample = {                                           # Creating a dictionary for images 
                'right_images': torch.FloatTensor(right_image),
                'right_embed': torch.FloatTensor(right_embed),
                'wrong_images': torch.FloatTensor(wrong_image),
                'inter_embed': torch.FloatTensor(inter_embed),
                'txt': str(txt)
                 }

        sample['right_images'] = sample['right_images'].sub_(127.5).div_(127.5)
        sample['wrong_images'] =sample['wrong_images'].sub_(127.5).div_(127.5)

        return sample

    def find_wrong_image(self, category):
        idx = np.random.randint(len(self.dataset_keys))
        example_name = self.dataset_keys[idx]
        example = self.dataset[self.split][example_name]
        _category = example['class']

        if _category != category:
            return example['img']

        return self.find_wrong_image(category)

    def find_inter_embed(self):
        idx = np.random.randint(len(self.dataset_keys))
        example_name = self.dataset_keys[idx]
        example = self.dataset[self.split][example_name]
        return example['embeddings']


    def validate_image(self, img):
        img = np.array(img, dtype=float)
        if len(img.shape) < 3:
            rgb = np.empty((64, 64, 3), dtype=np.float32)
            rgb[:, :, 0] = img
            rgb[:, :, 1] = img
            rgb[:, :, 2] = img
            img = rgb

        return img.transpose(2, 0, 1)

# %% [markdown]
# **Utility Class to Initialize And Save Model**

# %%
class Utils(object):     # Creating Pickle files for use in Future, to avoid re-training

    @staticmethod
    def smooth_label(tensor, offset):
        return tensor + offset

    @staticmethod
    def save_checkpoint(discriminator, generator, dir_path, subdir_path, epoch):
        path =  os.path.join(dir_path, subdir_path)
        if not os.path.exists(path):
            os.makedirs(path)

        torch.save(discriminator.state_dict(), '{0}/disc_{1}.pth'.format(path, epoch))
        torch.save(generator.state_dict(), '{0}/gen_{1}.pth'.format(path, epoch))

    @staticmethod
    def weights_init(m):
        classname = m.__class__.__name__
        if classname.find('Conv') != -1:
            m.weight.data.normal_(0.0, 0.02)       # Weight Initialization
        elif classname.find('BatchNorm') != -1:
            m.weight.data.normal_(1.0, 0.02)
            m.bias.data.fill_(0)

# %% [markdown]
# **Reading Input Data/Splitting Data**

# %%
traindata = Text2ImageDataset('flowers.hdf5', split=0)
traindata_loader = DataLoader(traindata, batch_size=64, shuffle=True,
                        num_workers=0)
valdata = Text2ImageDataset('flowers.hdf5', split=1)
valdata_loader = DataLoader(valdata, batch_size=64, shuffle=True,
                        num_workers=0)
testdata = Text2ImageDataset('flowers.hdf5', split=2)
testdata_loader = DataLoader(testdata, batch_size=64, shuffle=True,
                        num_workers=0)

# %%
print(len(testdata))
# Out:
# 5775

# %% [markdown]
# **Visualizing Input Dataset**

# %%
real_batch = next(iter(traindata_loader))
plt.figure(figsize=(8,8))
plt.axis("off")
plt.title("Training Images")
plt.imshow(np.transpose(vutils.make_grid(real_batch['right_images'].to(device)[:64], padding=2, normalize=True).cpu(),(1,2,0)))
plt.show()

# %% [markdown]
# **Helper Class For Plotting And Logging**

# %%
class Helper(object):
  @staticmethod
  def fakePlotter(img_list):    # Plotting Fake images generated by Generator through text embeddings and noise
    plt.subplot(1,2,2)
    plt.axis("off")
    plt.title("Fake Images")
    plt.imshow(np.transpose(img_list[-1].cpu().numpy(),(1,2,0)))
    plt.show()

  @staticmethod    # Printing Discriminator and Generator Loss
  def iteration_log(epoch, discriminator_loss, generator_loss, real_score, fake_score):
        print("Epoch: %d, discriminator_loss= %f, generator_loss= %f, D(X)= %f, D(G(X))= %f" % (epoch, discriminator_loss.data.cpu().mean(), generator_loss.data.cpu().mean(), real_score.data.cpu().mean(),fake_score.data.cpu().mean()))

# %% [markdown]
# **Loss Functions for Generator and Discriminator**

# %%
class generator_loss(torch.nn.Module):
    def __init__(self):
        super(generator_loss, self).__init__()
        self.estimator = nn.BCELoss()     # Based on log(1- D(G(z)))

    def forward(self, fake):
        batch_size = fake.size()[0]
        self.labels = Variable(torch.FloatTensor(batch_size).cuda().fill_(1))  # Generator always wants output as 1 indication real image
        return self.estimator(fake, self.labels)

class discriminator_loss(torch.nn.Module):
    def __init__(self):
        super(discriminator_loss, self).__init__()   # Based on log(D(x)) + log(1- D(G(z)))
        self.estimator = nn.BCELoss()     # Binary Cross Entropy Loss for Classification

    def forward(self, real, wrong, fake):
        batch_size = real.size()[0]
        self.real_labels = Variable(torch.FloatTensor(batch_size).cuda().fill_(1)) # Discriminator always wants output as 1 for real image
        self.fake_labels = Variable(torch.FloatTensor(batch_size).cuda().fill_(0)) # Discriminator always wants output as 0 for fake image
        return self.estimator(real, self.real_labels) + 0.5 * (self.estimator(wrong, self.fake_labels) + self.estimator(fake, self.fake_labels))

# %% [markdown]
# **Main DCGAN Class**

# %%
class DCGAN(object):
    def __init__(self, learning_rate, batch_size=64, epochs=1, pre_trained_gen=None, pre_trained_disc=None):

        self.generator = torch.nn.DataParallel(Generator())
        self.generator.apply(Utils.weights_init)
        self.discriminator = torch.nn.DataParallel(Discriminator())
        self.discriminator.apply(Utils.weights_init)

        self.noise_dim = 100
        self.l1_coef = 50    # Regularizers
        self.l2_coef = 100
        self.beta1 = 0.5     # Adam Optimizer hyperparameters

        self.batch_size = batch_size
        self.learning_rate = learning_rate
        self.num_epochs = epochs
        self.traindata_loader = traindata_loader
        self.valdata_loader = valdata_loader
        self.testdata_loader = testdata_loader

        self.optimize_discriminator = torch.optim.Adam(self.discriminator.parameters(), lr=self.learning_rate, betas=(self.beta1, 0.999))
        self.optimize_generator = torch.optim.Adam(self.generator.parameters(), lr=self.learning_rate, betas=(self.beta1, 0.999))

        self.checkpoints_path = 'Trainingnew/checkpoints'
        self.train_save_path = 'Trainingnew/res'
        self.val_save_path = 'Validationnew/valres'
        self.test_save_path = 'Testingnew/testres'

    def train_dcgan(self):
        criterion = nn.BCELoss() # Loss Function
        l2_loss = nn.MSELoss()
        l1_loss = nn.L1Loss()
        print("Running..................")
        for epoch in range(self.num_epochs):  # Ruuning epochs
            img_list = []
            iteration = 0
            for sample in self.traindata_loader:  # Iterating through Each data point
                Iterations.append(iteration)
                EpochsLib.append(epoch)
                iteration = iteration + 1
                right_images = sample['right_images']  # Real Images in Input Data
                right_embed = sample['right_embed']    # Converted Text embeddings from raw text
                wrong_images = sample['wrong_images']  # Fake Images in Input data

                right_images = Variable(right_images.float())
                right_embed = Variable(right_embed.float())
                wrong_images = Variable(wrong_images.float())

                real_labels = torch.ones(right_images.size(0))  # Real Labels
                fake_labels = torch.zeros(right_images.size(0)) # Fake Labels

                smoothed_real_labels = torch.FloatTensor(Utils.smooth_label(real_labels.numpy(), -0.1))

                real_labels = Variable(real_labels).cuda()
                smoothed_real_labels = Variable(smoothed_real_labels)
                fake_labels = Variable(fake_labels)

                # Train the discriminator model
                self.discriminator.zero_grad() # Clean Gradient buffer
                outputs, activation_real = self.discriminator(right_images, right_embed) # Run Discriminator
                real_loss = criterion(outputs, smoothed_real_labels)
                real_score = outputs

                noise = Variable(torch.randn(right_images.size(0), 100))
                noise = noise.view(noise.size(0), 100, 1, 1)
                fake_images = self.generator(right_embed, noise)   # Getting Fake images from Generator
                outputs, _ = self.discriminator(fake_images, right_embed)
                fake_loss = criterion(outputs, fake_labels)        # Finding loss by sending fake images to discriminator
                fake_score = outputs

                discriminator_loss = real_loss + fake_loss         # Total Discriminator loss

                discriminator_loss.backward()
                self.optimize_discriminator.step()

                # Train the generator model
                self.generator.zero_grad()
                noise = Variable(torch.randn(right_images.size(0), 100))
                noise = noise.view(noise.size(0), 100, 1, 1)
                fake_images = self.generator(right_embed, noise)
                outputs, activation_fake = self.discriminator(fake_images, right_embed)
                _, activation_real = self.discriminator(right_images, right_embed)

                activation_fake = torch.mean(activation_fake, 0)
                activation_real = torch.mean(activation_real, 0)
                
                # Regularization in Generator
                generator_loss = criterion(outputs, real_labels) + self.l2_coef * l2_loss(activation_fake, activation_real.detach()) + self.l1_coef * l1_loss(fake_images, right_images)

                generator_loss.backward()        
                self.optimize_generator.step()
                if (iteration%100)==0:
                    Helper.iteration_log(epoch,discriminator_loss, generator_loss, real_score, fake_score)
                img_list.append(vutils.make_grid(fake_images, padding=2, normalize=True))  # Fake images in a list
                Generator_losses.append(generator_loss.data.cpu().mean().item())
                Discriminator_losses.append(discriminator_loss.data.cpu().mean().item())
                Real_scores.append(real_score.data.cpu().mean().item())
                Fake_scores.append(fake_score.data.cpu().mean().item())
            #Helper.fakePlotter(img_list)
            #print("Done: ", epoch)
            Utils.save_checkpoint(self.discriminator, self.generator, self.checkpoints_path, '', epoch)
        print("Done..................")

    def train_predict(self):
        for sample in self.traindata_loader:
            right_images = sample['right_images']
            right_embed = sample['right_embed']
            txt = sample['txt']

            if not os.path.exists('resultsnew/{0}'.format(self.train_save_path)):
                os.makedirs('resultsnew/{0}'.format(self.train_save_path))

            right_images = Variable(right_images.float())
            right_embed = Variable(right_embed.float())

            noise = Variable(torch.randn(right_images.size(0), 100))
            noise = noise.view(noise.size(0), 100, 1, 1)
            fake_images = self.generator(right_embed, noise) # Getting fake images from training text inputs

            for image, t in zip(fake_images, txt):   # Storing Images in Folder
                im = Image.fromarray(image.data.mul_(127.5).add_(127.5).byte().permute(1, 2, 0).cpu().numpy())
                try:
                  im.save('resultsnew/{0}/{1}.jpg'.format(self.train_save_path, t.replace("/", "").replace(".\n", "").replace(" ", "")[:100]))
                except:
                  print('')
                print(t)
            break
    
    def val_predict(self):
        for sample in self.valdata_loader:
            right_images = sample['right_images']
            right_embed = sample['right_embed']
            txt = sample['txt']

            if not os.path.exists('resultsnew/{0}'.format(self.val_save_path)):
                os.makedirs('resultsnew/{0}'.format(self.val_save_path))

            right_images = Variable(right_images.float())
            right_embed = Variable(right_embed.float())

            noise = Variable(torch.randn(right_images.size(0), 100))
            noise = noise.view(noise.size(0), 100, 1, 1)
            fake_images = self.generator(right_embed, noise)

            for image, t in zip(fake_images, txt):
                im = Image.fromarray(image.data.mul_(127.5).add_(127.5).byte().permute(1, 2, 0).cpu().numpy())
                try:
                  im.save('resultsnew/{0}/{1}.jpg'.format(self.val_save_path, t.replace("/", "").replace(".\n", "").replace(" ", "")[:100]))
                except:
                  print('')
                print(t)
            break

    def test_predict(self):
        for sample in self.testdata_loader:
            right_images = sample['right_images']
            right_embed = sample['right_embed']
            txt = sample['txt']

            if not os.path.exists('resultsnew/{0}'.format(self.test_save_path)):
                os.makedirs('resultsnew/{0}'.format(self.test_save_path))

            right_images = Variable(right_images.float()).cuda()
            right_embed = Variable(right_embed.float()).cuda()

            noise = Variable(torch.randn(right_images.size(0), 100))
            noise = noise.view(noise.size(0), 100, 1, 1)
            fake_images = self.generator(right_embed, noise)

            for image, t in zip(fake_images, txt):
                im = Image.fromarray(image.data.mul_(127.5).add_(127.5).byte().permute(1, 2, 0).cpu().numpy())
                try:
                  im.save('resultsnew/{0}/{1}.jpg'.format(self.test_save_path, t.replace("/", "").replace(".\n", "").replace(" ", "")[:100]))
                except:
                  print('')
                print(t)
            break

# %% [markdown]
# **DCGAN Trainer**

# %%
Generator_losses = []
Discriminator_losses = []
Real_scores = []
Fake_scores = []
Iterations = []
EpochsLib = []
dcganmodel = DCGAN(0.0002, 64, 100, None, None)
dcganmodel.train_dcgan()
# Out:
# Running..................
# Epoch: 0, discriminator_loss= 2.767467, generator_loss= 29.748405, D(X)= 0.136636, D(G(X))= 0.000689
# Epoch: 99, discriminator_loss= 0.361867, generator_loss= 27.136362, D(X)= 0.883075, D(G(X))= 0.008487
# Epoch: 99, discriminator_loss= 0.361595, generator_loss= 26.483833, D(X)= 0.888939, D(G(X))= 0.010225
# Epoch: 99, discriminator_loss= 0.402765, generator_loss= 24.365868, D(X)= 0.820123, D(G(X))= 0.015722
# Done..................

# %% [markdown]
# **DCGAN Tester On Training Data**

# %%
dcganmodel.train_predict() # Input Text
# Out:
# this flower has yellow stamen surrounded by white petals with purple veins.
#
# the petals are coral red colored and the stamens are the same coral red color.
#
# five yellow oval shaped pedals surrounding yellow stigma and stamen.
#
# this flower has petals that are orange and has yellow stamen
#
# this flower is white in color, with petals that are curled on the edges.
#
# a blue flower with a white center and a white stamen at it's core.
#
# this flower is bright red along the edges of the circular petals, and yellow towards the center.
#
# this flower has layers of smooth rounded light pink petals.
#
# the petals on this flower are white and the pedicel is short and green
#
# this flower has petals which are faced down and are shaped like purple bells
#
# this flower has orange petals as well as a yellow stamen.
#
# a multiple layered flower with flat white petals at the bottom, long thin purple ones in the middle and orange tipped stamen at the top.
#
# a white multi petal with a yellow center on a short stem.
#
# deep lavender pointed petals with many yellow-white stamen
#
# this orange and pink flower has rounded petals and green sepals
#
# this flower has petals that are pink with yellow stamen
#
# this flower is pink in color, and has petals that are oval shaped and wavy.
#
# the petals on this flower are off white and the pistil is yellow
#
# this flower has petals that are purple with white dots
#
# this flower has a heart shaped pink petal with a waxy surface and deep veins along with an orange pistil.
#
# this flower has wide pink petals which curl outwards at their rounded tips.
#
# the pretty flower has large yellow petals the flow togetter.
#
# this flower has pink petals that droop with many pink stamen that stick out.
#
# this flower has thin, pointed pink leaves with veins surrounding white blossoms.
#
# this flower is yellow in color, with petals that are darker near the center.
#
# this flower has five conjoined pink petals which are soft and rounded.
#
# the flower has broad purple petals that are closely grouped together.
#
# this flower has deep red petals and soft, low pistil and stamen.
#
# this flower has a brown center surrounded by long yellow petals.
#
# this flower has petals that are blue and has white center
#
# the petals of this flower are lavender and the anther is golden yellow.
#
# the neon pink flower with many petals has a center row of yellow stamen and very dark green leaves.
#
# this flower is pink and white in color, and has petals that are striped in the center.
#
# a flower with separated white and orange petals with central bright yellow stigma
#
# this flower has spiky pink petals that are sparsely arranged and purple spiky sepals.
#
# this flower has very large all white petals with uneven edges that are folded downward.
#
# this flower is pink in color, with skinny and wrinkled petals.
#
# this flower has petals that are pink and has white shading
#
# this flower has small and very rounded red petals whose texture is very smooth.
#
# this flower has large white petals with yellow leading to the center.
#
# this is a flower with round orange petals on it.
#
# dark red petals green stem
#
# this is a pink flower with one large petal.
#
# this flower has petals that are red and has green patches
#
# a simple white trumpet shaped flower with no visible stamen or pistil and a bright green prominent pedicel.
#
# this flower has what appears to hundreds of think yellow petals.
#
# this flower has five smooth white petals which fade to bright yellow at the center.
#
# the flower is red with petals that are soft and separately arranged around stamens forming bowl shape
#
# the flower petals are oval shaped and white incolor withwhite spotted parts
#
# very few, yet large light purple petals that are pointed upward towards the sky.
#
# this flower has orange petals and a bright green pedicel
#
# this flower is yellow in color, with petals that have veins.
#
# this flower has a thick yellow stamen surrounded by smooth white petals.
#
# the pink petals are arranged in a star pattern standing around yellow stamen.
#
# this flower is purple in color, and has petals that are striped.
#
# this flower is white and pink in color, and has petals that are multi shaped.
#
# this flower has petals that are orange and has yellow shading
#
# these are bright red, glossy single petal flowers, with a thick white stigma.
#
# this flower has wide and very pale peach and orange petals with ruffled edges.
#
# the petals of the flower are red in color with small yellow berries.
#
# the petals are brilliant, with bright yellow edges and a dark red stripe down the center.
#
# this flower has tall prominent stamen surrounded by a wheel-shaped configuration of white petals with purple spots.
#
# this flower is pink and purple in color, with petals that are oval shaped.
#
# this is a multicolored flower with many petals and a green center.

# %% [markdown]
# **DCGAN Tester On Validation Data**

# %%
dcganmodel.val_predict()
# Out:
# this flower has a thick spiked green head and pointy, spiked pale purple petals.
#
# the flower has white petals that face down with green strip.
#
# the petals of this flower are purple and the pedicel is green
#
# this flower has petals that are purple with yellow stamen
#
# the petals of the flower are made from long purple filaments and are on top of a thorny base.
#
# this flower has a pink spider looking bloom with long pink stamen.
#
# this flower has light yellow pedals overlapping each other.
#
# this flower is purple and green in color, with petals that are curled upward.
#
# this unique flower hang down from its pedicel, with purple and white patterned petals.
#
# this flower has petals that are purple and are ruffled together
#
# this flower has a trumpeted star shape with petals of blue and indigo.
#
# this flower is white in color, and has petals that are oval shaped and drooping.
#
# this flower has petals that are purple with dark lines
#
# this is an odd shaped flower with stubby orange petals and green leafs.
#
# the bowl shaped white flower has petals that surrounding the stamen
#
# this flower has a large number of white petals with pink jagged edges that are all bunched together in an uneven fashion.
#
# the flower has a bunch of violet colored petals with some dots of black and purple in the inner portion.
#
# this flower has petals that are blue and are bunched together
#
# this flower has many red petals that are layered and open at the top of the plant.
#
# a ball of smaller pink flowers with long, protruding, pink stamens
#
# this flower is yellow and pink in color, with petals that are ruffled and bunched together.
#
# this flower has five very distinct white petals and a curved mouth of purple and yellow.
#
# these flowers have purple petals with smooth round edges and white stamen in the middle of them.
#
# white petals with yellow and purple middle dark green leaves
#
# this is a unique purple flower with leaves in the distance.
#
# this flower has green sepals surrounding several layers of overlapping, pointed pink petals.
#
# this flower has petals that are pink and are very thin
#
# the flower consists of round, red and white petals arranged close together, with a prominent pistil keeping them intact.
#
# pedicel are brown in color,petals are maroon and black in color
#
# this unique flower has petals with magenta pink at the bottom and white tips.
#
# this flower has very thin pink petals, a green stem, and a white pistil.
#
# this flower has petals that are white with purple and yellow in the center
#
# the pretty flowers has white petals and yellow in the middle.
#
# this flower has petals that are blue with yellow shading
#
# the flower has bright purple petals and its pistils are dark purple.
#
# this flower has petals that are purple with green stamen
#
# the purple petals of this flower are very light and dull in color.
#
# the flower has purple pedals with a gray and white ovary.
#
# this pale flower has light pink petals and white, pink and green stamen.
#
# this flower is made up of many rows of red pointy petals that get smaller closer to the pistil.
#
# this flower has petals that are pink and are very thin
#
# this flower has petals that are pink and very thin
#
# the flower has a purple petal with purple anther and filament
#
# this flower is red in color, with petals that are closely bunched together.
#
# this flower has many triangular shaped leaves of dusky green surrounding a flower of long purple filaments.
#
# this flower is pink and white in color, with petals that are bunched closely together.
#
# the petals are long, stiff and crinkled, yellow at the base and red on the ends, and the filaments are thick and long.
#
# this flower has petals that are red with green edges
#
# this flower is white and purple in color, with petals that are bulb shaped.
#
# this flower has petals that are pink with many layers
#
# a pink flowers and buds and the green leaves, pink anther and filament
#
# this flower is pink and yellow in color, and has petals that are wavy and multi colored.
#
# this flower has wide, spoon shaped purple petals.
#
# a flower with large ruffled purple petals with orange interior and white stamen.
#
# the flower has petals that form a ball around the stem.
#
# this flower has deep red petals as well as black stamen.
#
# this flower looks like it is comprised of numerous upright lavender threads about two or three inches long in a circle about five inches in diameter atop a green plant with many layers of protruding green pointed leaves.
#
# the purple petals are feather shaped and the anther is clustered in a pine cone shape.
#
# this flower is white and purple in color, and has petals that are in the shape of a circle.
#
# this flower has purple petals as well as a white pistil.
#
# this flower has extremely thick petals like artichoke thick and a huge center on top with hundreds of very long light purple stamen spiking out of it.
#
# this flower has very blue petals with yellow and green stamen in the middle that look sort of furry.
#
# a pinkish long pedaled flower with a very long stigma.
#
# this flower is purple and orange in color, with petals that are wavy and uneven.

# %% [markdown]
# **DCGAN Tester On Testing Data**

# %%
dcganmodel.test_predict()
# Out:
# a white flower with a long orange cob shaped pistil at it's center.
#
# this flower has three smooth petals that have pink and yellow stripes and one larger solid light pink petal.
#
# the flower shown has thin pink petals as its main feature.
#
# this white flower has five large horizontal petals and three vertical petals in the center.
#
# this flower is pink in color, with petals that are bell shaped.
#
# this flower is blue in color, with petals that have veins.
#
# this flower is white and yellow in color, with only one large petal.
#
# this flower is a beautiful color orange with overlapping petals.
#
# this flower has pink and white petals arranged in a non-uniform pattern.
#
# this flower has tall pink filaments with darker anthers and multicolored petals in varying shades of yellow, pink, and white.
#
# this flower is pink and yellow in color, with petals that are ruffled and wavy.
#
# long, narrow pink petals with a large round multicolored pistil.
#
# deep violet petals fold together over the pistil of this flower, tapering to a slender point.
#
# a large, spiral-shaped white petal encircles the compact cylindrical yellow stamens and pistil in these flowers.
#
# this flower has petals that are white and has red dots
#
# this flower has petals that are white and are bunched together
#
# this is a flower with several smaller petals that are bright orange and yellow in color, the petals are toothed at the edge.
#
# the flower is big with thick petals that are arranged around a huge bunch of stamen
#
# a flower with long and narrow petals that are pointed and orange.
#
# the pedals of this flower are red with a long stigma
#
# this is a small flower with blue petals and green ovary.
#
# the flower shown has pointy yellow petals with blue pistil
#
# this flower is bright yellow a base color of yellow on its petals with purple dots
#
# this flower has thin purple petals that trumpet out and expose a single yellow pistal in the center.
#
# this flower has large and very smooth white petals with plain soft edges and a yellow mouth.
#
# these flowers have round lavender and white petals with brown specks on them.
#
# this flower has pink petals as well as a green pedicel.
#
# this flower has a dense set of thin yellow petals and a round pistil.
#
# this flower has petals that are yellow and very thin
#
# the petals on this flower are pink with some brown, white and yellow spots.
#
# the flower has many yellow stamens around the orange pollen tube
#
# this unusual flower has long thin red pointed petals with long whispy white stamen.
#
# this flower has orange petals, and a pink and green pedicle along with a purple pollen tube.
#
# these flowers have three petals which are white and have a yellow center.
#
# outer petals are green incolo,inner petals are yellow in color
#
# this multi-colored flower has striped petals as its main feature.
#
# this flower has white furry petals with many green pointed ovaries.
#
# this flower has bright yellow petals and a long green stem.
#
# there are purple leaves with curled edges and prominent veins supported by a pale green sepal and pedicel.
#
# the petals of the flower have a shape that resembles a four leaf clover, and have various shades of green, red, and yellow.
#
# this flower has round white petals on either side and white petals toward the center with red hash marks covering the petals.
#
# this flower is orange with black lines on the petals with red filaments.
#
# the flower has hundreds of pin like petals that are really slender and yellow in color.
#
# the petals of this flower are pink and the pistil is red
#
# this flower has large purple petals and a light blue colored stigma.
#
# this flower has petals that are pink and has white shading
#
# this flower has yellow and purplish petals, a yellow stigma, a white pollen tube, and a green pedicel.
#
# a tiny purple petal with dark purple veins and a dove wing shape.
#
# a purple flower with ruffled petals and a green pedicle and sepal.
#
# this pale purple flower has spike like petals with no clearly visible stamen or stigma.
#
# this flower has petals that are yellow with small black lines
#
# the petals of the flower are narrow and extremely pointy, and consist of shades of yellow, blue and orange.
#
# this flower is pink and white in color, with petals that are striped.
#
# this is a flower with many pink and white petals onit.
#
# the flower is pink in coloor and contains a one rounded petal with smaller sized stamens
#
# this flower is trumpet shaped with pink petals and lime green pedicel.
#
# this flower has petals that are pink and has red stamen
#
# this flower has five long sharp orange petals with a dark purple pistil.
#
# this flower has white petals as well as a green pedicel.
#
# this flower is orange and black in color, with petals that are spotted.
#
# this flower is pink in color, and has petals that are wavy and rounded.
#
# this flower has a large number of very thin bright yellow petals in a ring configuration.
#
# this flower has narrow orange petals that are lighter toward the center and numerous yellow anthems that create a broad center.
#
# this flower has red petals as well as a red pistil.

# %% [markdown]
# **Plotting Results Of Generated Images From Test Data**

# %%
dataroot = "resultsnew/resultsnew/Testingnew/"
plotdataset = dset.ImageFolder(root=dataroot,
                           transform=transforms.Compose([
                               transforms.Resize(64),
                               transforms.CenterCrop(64),
                               transforms.ToTensor(),
                               transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5)),
                           ]))
dataloader = torch.utils.data.DataLoader(plotdataset, batch_size=64,
                                         shuffle=True, num_workers=2)

real_batch = next(iter(dataloader))
plt.figure(figsize=(8,8))
plt.axis("off")
plt.title("Fake Generated Images")
plt.imshow(np.transpose(vutils.make_grid(real_batch[0].to(device)[:64], padding=2, normalize=True).cpu(),(1,2,0)))

# %% [markdown]
# **Plotting Generator And Discriminator Losses and Scores During Training**

# %%
plt.figure(figsize=(10,5))
plt.title("Generator, Discriminator Loss During Training")
plt.plot(Generator_losses,label="G")
plt.plot(Discriminator_losses,label="D")
plt.xlabel("iterations")
plt.ylabel("Loss")
plt.legend()
plt.show()

plt.figure(figsize=(10,5))
plt.title("Discriminator Real, Fake Scores During Training")
plt.plot(Real_scores,label="R")
plt.plot(Fake_scores,label="F")
plt.xlabel("iterations")
plt.ylabel("Scores")
plt.legend()
plt.show()

# %% [markdown]
# **Saving Losses To CSV For Future Analysis**

# %%
import pickle
import pandas as pd

outfile = 'epoch_loss_new.csv'

output_file = open(outfile, "w")
dataframe_dict = {"Epoch" : [], "Iteration": [], "GeneratorLoss": [], "DiscriminatorLoss": [], "RealScore": [], "FakeScore": []}

for i in range(0, len(Iterations)):
    dataframe_dict['Epoch'].append(EpochsLib[i])
    dataframe_dict['Iteration'].append(Iterations[i])
    dataframe_dict['GeneratorLoss'].append(Generator_losses[i])
    dataframe_dict['DiscriminatorLoss'].append(Discriminator_losses[i])
    dataframe_dict['RealScore'].append(Real_scores[i])
    dataframe_dict['FakeScore'].append(Fake_scores[i])

df = pd.DataFrame(data=dataframe_dict)
df.to_csv(outfile, index=False)
print("Written to csv file {}".format(outfile))
# Out:
# Written to csv file epoch_loss_new.csv
